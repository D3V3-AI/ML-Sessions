# %% [markdown]
# # ML Sessions  #1 - MNIST sin librerias
#
# This notebook is part of the ML Sessions series by >_ D3V³, where we explore various machine learning concepts and techniques through practical examples and code implementations.

# %%
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# quick visualization of the data
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
for i in range(5):
    subplot = fig.add_subplot(1, 5, i + 1)
    subplot.imshow(X_train[i], cmap=plt.cm.binary)
    subplot.set_title(f"Label: {y_train[i]}")
    subplot.axis('off')

plt.show()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
# %run mnist.py
# Out:
# help functions created
# data created
# preprocessing done
# weights and bias done
# starting training
#
#
#
# Epoch 01/10 | Loss: 1.7706 | Train Acc: 0.6036 | Test Acc: 0.6116
# Epoch 02/10 | Loss: 1.3113 | Train Acc: 0.6565 | Test Acc: 0.6632
# Epoch 03/10 | Loss: 1.0991 | Train Acc: 0.7057 | Test Acc: 0.7141
# Epoch 04/10 | Loss: 0.9716 | Train Acc: 0.7079 | Test Acc: 0.7170
# Epoch 05/10 | Loss: 0.8865 | Train Acc: 0.7297 | Test Acc: 0.7382
# Epoch 06/10 | Loss: 0.8197 | Train Acc: 0.7542 | Test Acc: 0.7639
# Epoch 07/10 | Loss: 0.7680 | Train Acc: 0.7641 | Test Acc: 0.7677
# Epoch 08/10 | Loss: 0.7232 | Train Acc: 0.7828 | Test Acc: 0.7884
# Epoch 09/10 | Loss: 0.6888 | Train Acc: 0.7845 | Test Acc: 0.7886
# Epoch 10/10 | Loss: 0.6577 | Train Acc: 0.7984 | Test Acc: 0.8028
# Final Test Accuracy: 0.8028

# %%
y_pred, _ = forward_pass(X_test, W1, B1, W2, B2)

# %%
import numpy as np
random_index = np.random.randint(0, X_test.shape[0])
random_image = X_test[random_index].reshape(28, 28) 
predicted = np.argmax(y_pred[random_index])
label = np.argmax(y_test[random_index])
plt.imshow(random_image, cmap='gray')
plt.title(f"True label: {label} | Predicted label: {predicted}")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))
